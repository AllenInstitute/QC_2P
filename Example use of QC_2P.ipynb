# %%
import qc_2p

# %% [markdown]
# Instantiate the class on an hdf5 file

# %%
h5_path = '/allen/programs/braintv/production/visualbehavior/prod0/specimen_795522276/ophys_session_832490712/ophys_experiment_832802571/832802571.h5'
qc_analysis = qc_2p.Qc2p(filepath = h5_path)

# %% [markdown]
# Get the various metrics to convert pixels into photons flux as well as the median photon flux in the movie

# %%
qc_analysis.get_photon_metrics()
# Out:
# {'photon_flux_median': 0.029637759663183147,
#  'photon_gain': 6808.255250188489,
#  'background_noise': 1466.2185671693087,
#  'photon_offset': -9982390.25785429}

# %% [markdown]
# Plot the variance against the mean for this movie, veryfying that the data is poisson limited.

# %%
fig = qc_analysis.plot_poisson_curve()
